# %% [markdown]
# # Pandas and Matplotlib Homework

# %% [markdown]
# ### Q1A) Create a new DF (*called NHL_Ones*) by:
# #### Filtering the correct DF for Goalies that played 1 game <font color='red'> (GP = Games played)</font>

# %% [markdown]
# Notes: How would you find the 'GP' column in these files?

# %%
#Answer 1A:

#1. Load excel file in Pandas
#2. Find GP Column
#3. Filter by those who played one game

NHL_Goalies = pd.read_excel('NHLGoalies2016_2017.xls',na_values='',sheet_name=0)
# NHL_Goalies.loc[NHL_Goalies["GP"] == 1]
NHL_Ones = NHL_Goalies
NHL_Ones.loc[NHL_Ones["GP"] == 1]
# Out:
#       Last Name First Name Team         DOB        Birth City  S/P Cntry  Nat  \
# 1         Alves      Jorge  CAR  1979-01-30            Boston   MA   USA  USA
# 13     Campbell       Jack  LAK  1992-01-09        Port Huron   MI   USA  USA
# 14       Comrie       Eric  WPG  1995-07-06          Edmonton   AB   CAN  CAN
# 16       Copley    Pheonix  STL  1992-01-18        North Pole   AK   USA  USA
# 22     Driedger      Chris  OTT  1994-05-18          Winnipeg   MB   CAN  CAN
# 27     Forsberg      Anton  CBJ  1992-11-27         Härnösand  NaN   SWE  SWE
# 29      Gillies        Jon  CGY  1994-01-22           Concord   NH   USA  USA
# 32   Gudlevskis   Kristers  TBL  1992-07-31        Aizkraukle  NaN   LVA  LVA
# 42        Jarry    Tristan  PIT  1995-04-29            Surrey   BC   CAN  CAN
# 50    Langhamer      Marek  ARI  1994-07-22  Moravska Trebova  NaN   CZE  CZE
# 67  Nedeljkovic       Alex  CAR  1996-01-07             Parma   OH   USA  USA
# 80      Rittich      David  CGY  1992-08-19           Jihlava  NaN   CZE  CZE
# 87       Subban    Malcolm  BOS  1993-12-21           Toronto   ON   CAN  CAN
# 89     Tokarski     Dustin  ANA  1989-09-16            Watson   SK   CAN  CAN
# 90      Ullmark      Linus  BUF  1993-07-31           Lugnvik  NaN   SWE  SWE
#
#     Ht   Wt  ...    Cap Hit        Pace  1st  2nd  3rd  Star  GPS  Ginj  \
# 1   69  185  ...        NaN    0.000000  NaN  NaN  NaN   NaN  0.0   NaN
# 13  74  197  ...        NaN   96.000000  NaN  NaN  NaN   NaN  0.1   NaN
# 14  73  175  ...   645000.0  124.451939  NaN  NaN  NaN   NaN  0.2   NaN
# 16  76  196  ...   708750.0  104.864253  NaN  NaN  NaN   NaN -0.1   NaN
# 22  76  205  ...   755000.0  123.000000  NaN  NaN  NaN   NaN -0.2   NaN
# 27  75  192  ...   650000.0  110.611664  NaN  NaN  NaN   NaN  0.0   NaN
# 29  78  223  ...   925000.0  109.000000  1.0  0.0  0.0   1.0  0.3   NaN
# 32  75  223  ...        NaN  125.764192  NaN  NaN  NaN   NaN  0.0   NaN
# 42  74  194  ...   630833.0  107.234043  NaN  NaN  NaN   NaN  0.0   NaN
# 50  74  193  ...   648333.0   88.936627  NaN  NaN  NaN   NaN  0.0   NaN
# 67  72  198  ...        NaN  102.170284  NaN  NaN  NaN   NaN  0.3   NaN
# 80  75  202  ...        NaN  108.000000  NaN  NaN  NaN   NaN  0.0   NaN
# 87  74  200  ...   863333.0  107.843137  NaN  NaN  NaN   NaN -0.1   NaN
# 89  72  205  ...        NaN   91.993186  NaN  NaN  NaN   NaN  0.1   NaN
# 90  76  221  ...   775833.0  100.113507  NaN  NaN  NaN   NaN  0.2   NaN
#
#     Injuries  CHIP
# 1        NaN
# 13       NaN
# 14       NaN
# 16       NaN
# 22       NaN
# 27       NaN
# 29       NaN
# 32       NaN
# 42       NaN
# 50       NaN
# 67       NaN
# 80       NaN
# 87       NaN
# 89       NaN
# 90       NaN
#
# [15 rows x 111 columns]

# %% [markdown]
#  ## Q1B)
#  #### A. Find the value of the minimum Salary for the entire dataset
#  #### B. Replace the missing values from the NHL_Ones DF with this
#  #### C. Create a new DF after replacement by **adding** a column called  "Adjusted_Salary"
#  #### D. I would like to only see the old "Salary" column and the "Adjusted Salary" column from the new Dataframe

# %% [markdown]
# #### Notes:
# 1. Note where the minimum Salary value is coming & where you are going to assign it to
# 2. Read up on **replacement** of missing values
# 3. Look up Numpy definition for null
# 4. Look up Pandas **Series** Naming
# 5. Review concat function in Pandas
# 6. Review how to slice columns

# %%
#Answer 1B:
NHL_Goalies = pd.read_excel('NHLGoalies2016_2017.xls',na_values='',sheet_name=0)


list(NHL_Goalies)

# Original Missing Salary Column
NHL_Ones = NHL_Goalies.loc[NHL_Goalies["GP"] == 1]
print(NHL_Ones["Salary"])

# Adjusted Salary Column
NHL_Ones = NHL_Goalies.loc[NHL_Goalies["GP"] == 1]
values = {"Salary": 575000}
Adjusted_Salary = NHL_Ones.fillna(value = values)
print(Adjusted_Salary["Salary"])
# Out:
# 1          NaN
# 13         NaN
# 14    575000.0
# 16    708750.0
# 22    780000.0
# 27    650000.0
# 29    925000.0
# 32         NaN
# 42    575000.0
# 50    673334.0
# 67         NaN
# 80         NaN
# 87    832500.0
# 89         NaN
# 90    892500.0
# Name: Salary, dtype: float64
# 1     575000.0
# 13    575000.0
# 14    575000.0
# 16    708750.0
# 22    780000.0
# 27    650000.0
# 29    925000.0
# 32    575000.0
# 42    575000.0
# 50    673334.0
# 67    575000.0
# 80    575000.0
# 87    832500.0
# 89    575000.0
# 90    892500.0
# Name: Salary, dtype: float64

# %%
#Answer 3B here; Please comment each part

Missing_Cols = pd.read_excel('NHLGoalies2016_2017.xls',na_values='',sheet_name=0) # load the excel file 
for i in range(len(Missing_Cols.index)): # iterative loop
    print("Missing Values in Row", i, ": ", Missing_Cols.iloc[i].isnull().sum()) 
    # sums up all instances of missing data in each row
# Out:
# Missing Values in Row 0 :  3
# Missing Values in Row 1 :  18
# Missing Values in Row 2 :  2
# Missing Values in Row 3 :  1
# Missing Values in Row 4 :  3
# Missing Values in Row 5 :  1
# Missing Values in Row 6 :  8
# Missing Values in Row 7 :  3
# Missing Values in Row 8 :  7
# Missing Values in Row 9 :  0
# Missing Values in Row 10 :  4
# Missing Values in Row 11 :  3
# Missing Values in Row 12 :  4
# Missing Values in Row 13 :  11
# Missing Values in Row 14 :  7
# %%
#Answer 4 here: pleae comment 
# create two separate histograms 
#Answer 4 here: please comment
# TWO SEPARATE HISTOGRAMS
# ONE HISTOGRAM: All GAA of NHL
# OTHER HISTOGRAM: The subset

import numpy as np
import pandas as pd
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

# Code for first histogram, entire set

NHL_Goalies = pd.read_excel('NHLGoalies2016_2017.xls',na_values='',sheet_name=0) # Load file
GAA_Variable = NHL_Goalies['GAA'] # extracting GAA column and putting in into GAA_Variable
plt.hist([GAA_Variable], color=['orange']) # plotting histogram, changing color
plt.xlabel("GAA Values") # X Label
plt.ylabel("Frequency") # Y Label
plt.xticks(range(0, 7)) # Hash marks in X axis
plt.yticks(range(1, 50)) # Hash marks in Y axis
plt.title('Entire Set') # Title
plt.show()

# Code for second histogram, subset

NHL_Goalies = pd.read_excel('NHLGoalies2016_2017.xls',na_values='',sheet_name=0) # Load file
# GAA_Variable = NHL_Goalies['GAA'] # extracting GAA column and putting in into GAA_Variable

Workhorse = NHL_Goalies[(NHL_Goalies["GP"] > 25) & (NHL_Goalies["GAA"] < 3.00)]
Workhorse = Workhorse.values
plt.hist([Workhorse], color=['blue']) # plotting histogram, changing color
plt.xlabel("GAA Values") # X Label
plt.ylabel("Frequency") # Y Label
plt.xticks(range(0, 3)) # Hash marks in X axis
plt.yticks(range(1, 50)) # Hash marks in Y axis
plt.title('Subset') # Title
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-24862bf5651d> in <module>()
#      30 Workhorse = NHL_Goalies[(NHL_Goalies["GP"] > 25) & (NHL_Goalies["GAA"] < 3.00)]
#      31 Workhorse = Workhorse.values
# ---> 32 plt.hist([Workhorse], color=['blue']) # plotting histogram, changing color
#      33 plt.xlabel("GAA Values") # X Label
#      34 plt.ylabel("Frequency") # Y Label
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3130                       histtype=histtype, align=align, orientation=orientation,
#    3131                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3132                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3133     finally:
#    3134         ax._hold = washold
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in hist(***failed resolving arguments***)
#    6469             x = [np.array([])]
#    6470         else:
# -> 6471             x = cbook._reshape_2D(x, 'x')
#    6472         nx = len(x)  # number of datasets
#    6473
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in _reshape_2D(X, name)
#    2086         return [np.reshape(x, -1) for x in X]
#    2087     else:
# -> 2088         raise ValueError("{} must have 2 or fewer dimensions".format(name))
#    2089
#    2090
#
# ValueError: x must have 2 or fewer dimensions

# %% [markdown]
# ### Q5) GroupBy Question
# ##### 1. Subset the NHL_Goalies DataFrame where Injuries is not known <font color='red'>(Injuries=NaN)</font>;
# ##### 2. Use a Merge with the GAA_  DF to produce a NEW DF (*called mergedDF*)
# ###### *** USE A JOIN THAT PRESERVES ORDER AND USES THE INTERSECTION OF KEYS***
# ###### *** USE BOTH THE LEFT AND RIGHT INDEXES AS JOIN KEYS***
# ##### 3. From the mergedDF keep FirstName/LastName/Team/Cntry/ SV% /GA/GAA/ TOI (note one copy for any duplicate column)
# ##### 4. GroupBy country on mergedDF and aggregate The Means, Mins, and Maximum of the kept columns
# #### 5. Create a dataframe of the <font color='red'>TOI </font>groupby object and write it to a comma seperated value file called ('TOI_2017.csv')

# %% [markdown]
# ## Notes:
#
# 1. Review or read up pandas documentation on:
#     - how to create selection criteria
#     - how aggs/joins work: https://pandas.pydata.org/pandas-docs/stable/merging.html
# 2. https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.to_csv.html
# 3. https://stackoverflow.com/questions/14734533/how-to-access-pandas-groupby-dataframe-by-key
# 4. https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.get.html

# %%
#Answer 5 here: please comments
# Subset of Players with NaN injuries
NHL_Goalies = pd.read_excel('NHLGoalies2016_2017.xls',na_values='',sheet_name=0)
Injuries_df = NHL_Goalies.loc[(NHL_Goalies["Injuries"].isnull())]
print(Injuries_df)

# Location of GAA Column
NHL_Goalies = pd.read_excel('NHLGoalies2016_2017.xls',na_values='',sheet_name=0)
GAA_df = NHL_Goalies.loc[(NHL_Goalies["GAA"])]
print(GAA_df)


# Subset of Players with NaN injuries
# NHL_Goalies = pd.read_excel('NHLGoalies2016_2017.xls',na_values='',sheet_name=0)
# null_columns= NHL_Goalies.columns[NHL_Goalies.isnull().any()]
# print(NHL_Goalies[NHL_Goalies["Injuries"].isnull()][null_columns])

# Creation of Merged Dataframe
# mergedDF = pd.merge(Injuries_df, GAA_df, right_index=True, left_index=True)
# print(mergedDF)

# MergedDF = pd.concat([Injuries_df, GAA_df], axis=1)
# print(MergedDF)

MergedDF = pd.concat([Injuries_df, GAA_df], axis = 1, ignore_index=True)
print(MergedDF)
# Out:
#       Last Name     First Name      Team         DOB        Birth City  S/P  \
# 0         Allen           Jake       STL  1990-08-07       Fredericton   NB
# 1         Alves          Jorge       CAR  1979-01-30            Boston   MA
# 4       Bachman        Richard       VAN  1987-07-25    Salt Lake City   UT
# 6         Berra           Reto       FLA  1987-01-03            Bulach  NaN
# 7        Berube  Jean-Francois       NYI  1991-07-13        Repentigny   QC
# 8        Bibeau        Antoine       TOR  1994-05-01     Victoriaville   QC
# 11     Brossoit        Laurent       EDM  1993-03-23      Port Alberni   BC
# 12        Budaj          Peter  LAK, TBL  1982-09-18   Banská Bystrica  NaN
# 13     Campbell           Jack       LAK  1992-01-09        Port Huron   MI
# 14       Comrie           Eric       WPG  1995-07-06          Edmonton   AB
# 15       Condon           Mike  PIT, OTT  1990-04-27         Holliston   MA
# 16       Copley        Pheonix       STL  1992-01-18        North Pole   AK
# 17       Coreau          Jared       DET  1991-11-05             Perth   ON
# 20         Dell          Aaron       SJS  1989-05-04           Airdrie   AB
# 22     Driedger          Chris       OTT  1994-05-18          Winnipeg   MB
# 23       Dubnyk          Devan       MIN  1986-05-04            Regina   SK
# 25       Enroth         Jhonas       TOR  1988-06-25         Stockholm  NaN
# 26       Fleury     Marc-Andre       PIT  1984-11-28             Sorel   QC
# 27     Forsberg          Anton       CBJ  1992-11-27         Härnösand  NaN
# 29      Gillies            Jon       CGY  1994-01-22           Concord   NH
# 30       Greiss         Thomas       NYI  1986-01-29            Fussen  NaN
# 31     Grubauer        Philipp       WSH  1991-11-25         Rosenheim  NaN
# 32   Gudlevskis       Kristers       TBL  1992-07-31        Aizkraukle  NaN
# 34        Halak       Jaroslav       NYI  1985-05-13        Bratislava  NaN
# 36     Hellberg         Magnus       NYR  1991-04-04           Uppsala  NaN
# 37   Hellebuyck         Connor       WPG  1993-05-19          Commerce   MI
# 38       Holtby         Braden       WSH  1989-09-16      Lloydminster   SK
# 40   Hutchinson        Michael       WPG  1990-03-02            Barrie   ON
# 41       Hutton         Carter       STL  1985-12-19       Thunder Bay   ON
# 42        Jarry        Tristan       PIT  1995-04-29            Surrey   BC
# 44        Jones         Martin       SJS  1990-01-10   North Vancouver   BC
# 47    Korpisalo         Joonas       CBJ  1994-04-28              Pori  NaN
# 48      Kuemper          Darcy       MIN  1990-05-05         Saskatoon   SK
# 50    Langhamer          Marek       ARI  1994-07-22  Moravska Trebova  NaN
# 52     Lehtonen           Kari       DAL  1983-11-16          Helsinki  NaN
# 53     Leighton        Michael       CAR  1981-05-19          Petrolia   ON
# 54     Lindgren        Charlie       MTL  1993-12-18         Lakeville   MN
# 58       Martin        Spencer       COL  1995-06-08          Oakville   ON
# 60      Mazanec          Marek       NSH  1991-07-18             Pisek  NaN
# 61   McElhinney         Curtis  CBJ, TOR  1983-05-23            London   ON
# 62     McIntyre           Zane       BOS  1992-08-20       Grand Forks   ND
# 65       Mrazek           Petr       DET  1992-02-14           Ostrava  NaN
# 67  Nedeljkovic           Alex       CAR  1996-01-07             Parma   OH
# 69        Niemi          Antti       DAL  1983-08-29            Vantaa  NaN
# 72       Peters         Justin       ARI  1986-08-30             Blyth   ON
# 73      Pickard         Calvin       COL  1992-04-15           Moncton   NB
# 80      Rittich          David       CGY  1992-08-19           Jihlava  NaN
# 81        Saros          Juuse       NSH  1995-04-19            Forssa  NaN
# 82    Schneider           Cory       NJD  1986-03-18        Marblehead   MA
# 83        Smith         Jeremy       COL  1989-04-13          Dearborn   MI
# 85      Stalock           Alex       MIN  1987-07-28          St. Paul   MN
# 86      Stolarz        Anthony       PHI  1994-01-20            Edison   NJ
# 87       Subban        Malcolm       BOS  1993-12-21           Toronto   ON
# 88       Talbot            Cam       EDM  1987-07-05         Caledonia   ON
# 89     Tokarski         Dustin       ANA  1989-09-16            Watson   SK
# 90      Ullmark          Linus       BUF  1993-07-31           Lugnvik  NaN
# 92  Vasilevskiy         Andrei       TBL  1994-07-25            Tyumen  NaN
# 93         Ward            Cam       CAR  1984-02-29         Saskatoon   SK
#
#    Cntry  Nat  Ht   Wt  ...     Cap Hit        Pace   1st  2nd  3rd  Star  \
# 0    CAN  CAN  74  203  ...   2350000.0  104.033662   9.0  7.0  6.0  22.0
# 1    USA  USA  69  185  ...         NaN    0.000000   NaN  NaN  NaN   NaN
# 4    USA  USA  70  183  ...    575000.0  113.421038   1.0  0.0  1.0   2.0
# 6    CHE  CHE  76  210  ...   1450000.0  108.457976   NaN  NaN  NaN   NaN
# 7    CAN  CAN  73  177  ...    675000.0  114.005505   0.0  1.0  1.0   2.0
# 8    CAN  CAN  75  210  ...    655000.0  130.294240   NaN  NaN  NaN   NaN
# 11   CAN  CAN  75  204  ...    750000.0  110.633178   1.0  1.0  0.0   2.0
# 12   SVK  SVK  73  196  ...    600000.0  108.110995   4.0  7.0  4.0  15.0
# 13   USA  USA  74  197  ...         NaN   96.000000   NaN  NaN  NaN   NaN
# 14   CAN  CAN  73  175  ...    645000.0  124.451939   NaN  NaN  NaN   NaN
# 15   USA  USA  74  197  ...    575000.0  112.079733   9.0  1.0  4.0  14.0
# 16   USA  USA  76  196  ...    708750.0  104.864253   NaN  NaN  NaN   NaN
# 17   CAN  CAN  78  220  ...    612500.0  108.674473   1.0  1.0  1.0   3.0
# 20   CAN  CAN  72  205  ...    625000.0  114.105623   3.0  3.0  2.0   8.0
# 22   CAN  CAN  76  205  ...    755000.0  123.000000   NaN  NaN  NaN   NaN
# 23   CAN  CAN  78  213  ...   4333333.0  109.334753   8.0  6.0  8.0  22.0
# 25   SWE  SWE  70  175  ...    750000.0  112.377019   NaN  NaN  NaN   NaN
# 26   CAN  CAN  74  180  ...   5750000.0  117.360311   5.0  3.0  3.0  11.0
# 27   SWE  SWE  75  192  ...    650000.0  110.611664   NaN  NaN  NaN   NaN
# 29   USA  USA  78  223  ...    925000.0  109.000000   1.0  0.0  0.0   1.0
# 30   DEU  DEU  73  228  ...   1500000.0  115.658454   2.0  6.0  6.0  14.0
# 31   DEU  DEU  73  182  ...    750000.0  106.281467   6.0  1.0  0.0   7.0
# 32   LVA  LVA  75  223  ...         NaN  125.764192   NaN  NaN  NaN   NaN
# 34   SVK  SVK  71  181  ...   4500000.0  116.862004   4.0  1.0  1.0   6.0
# 36   SWE  SWE  78  209  ...    625000.0  111.568669   0.0  0.0  1.0   1.0
# 37   USA  USA  76  207  ...    667500.0  107.597892   7.0  1.0  2.0  10.0
# 38   CAN  CAN  74  217  ...   6100000.0  109.755899  11.0  8.0  7.0  26.0
# 40   CAN  CAN  75  202  ...   1150000.0  104.430472   2.0  1.0  1.0   4.0
# 41   CAN  CAN  73  195  ...   1125000.0  104.040300   5.0  3.0  1.0   9.0
# 42   CAN  CAN  74  194  ...    630833.0  107.234043   NaN  NaN  NaN   NaN
# 44   CAN  CAN  76  190  ...   3000000.0  114.352625   9.0  1.0  6.0  16.0
# 47   FIN  FIN  75  190  ...    742500.0  113.014695   1.0  1.0  1.0   3.0
# 48   CAN  CAN  77  215  ...   1550000.0  114.868159   3.0  0.0  0.0   3.0
# 50   CZE  CZE  74  193  ...    648333.0   88.936627   NaN  NaN  NaN   NaN
# 52   FIN  FIN  76  190  ...   5900000.0  114.649922   5.0  3.0  3.0  11.0
# 53   CAN  CAN  75  186  ...    700000.0  108.425141   1.0  0.0  0.0   1.0
# 54   USA  USA  74  190  ...    925000.0   97.124076   0.0  0.0  1.0   1.0
# 58   CAN  CAN  75  210  ...    728333.0  110.013004   NaN  NaN  NaN   NaN
# 60   CZE  CZE  76  187  ...    575000.0  118.592210   NaN  NaN  NaN   NaN
# 61   CAN  CAN  75  200  ...    800000.0  119.984136   3.0  1.0  2.0   6.0
# 62   USA  USA  74  206  ...    925000.0  118.334419   NaN  NaN  NaN   NaN
# 65   CZE  CZE  74  183  ...   4000000.0  101.689696   3.0  4.0  6.0  13.0
# 67   USA  USA  72  198  ...         NaN  102.170284   NaN  NaN  NaN   NaN
# 69   FIN  FIN  74  215  ...   4500000.0  120.208273   5.0  2.0  0.0   7.0
# 72   CAN  CAN  73  210  ...    600000.0  101.115987   NaN  NaN  NaN   NaN
# 73   CAN  CAN  73  200  ...   1000000.0  106.926059   3.0  4.0  8.0  15.0
# 80   CZE  CZE  75  202  ...         NaN  108.000000   NaN  NaN  NaN   NaN
# 81   FIN  FIN  71  180  ...    692500.0  112.507813   4.0  1.0  5.0  10.0
# 82   USA  USA  75  205  ...   6000000.0   99.791717   5.0  4.0  7.0  16.0
# 83   USA  USA  72  177  ...    675000.0  106.464392   0.0  0.0  1.0   1.0
# 85   USA  USA  72  187  ...    650000.0  100.911002   0.0  0.0  1.0   1.0
# 86   USA  USA  78  210  ...    753333.0  106.891203   1.0  1.0  1.0   3.0
# 87   CAN  CAN  74  200  ...    863333.0  107.843137   NaN  NaN  NaN   NaN
# 88   CAN  CAN  75  199  ...   4166667.0  112.035398  11.0  8.0  2.0  21.0
# 89   CAN  CAN  72  205  ...         NaN   91.993186   NaN  NaN  NaN   NaN
# 90   SWE  SWE  76  221  ...    775833.0  100.113507   NaN  NaN  NaN   NaN
# 92   RUS  RUS  75  207  ...    925000.0  108.651016   4.0  8.0  2.0  14.0
# 93   CAN  CAN  73  185  ...   3300000.0  108.609467   5.0  6.0  6.0  17.0
#
#      GPS  Ginj  Injuries  CHIP
# 0    9.8   NaN       NaN
# 1    0.0   NaN       NaN
# 4    1.1   NaN       NaN
# 6    0.2   NaN       NaN
# 7    0.8   NaN       NaN
# 8    0.4   NaN       NaN
# 11   1.2   NaN       NaN
# 12   8.6   NaN       NaN
# 13   0.1   NaN       NaN
# 14   0.2   NaN       NaN
# 15   6.8   NaN       NaN
# 16  -0.1   NaN       NaN
# 17   1.0   NaN       NaN
# 20   4.2   NaN       NaN
# 22  -0.2   NaN       NaN
# 23  13.1   NaN       NaN
# 25   0.2   NaN       NaN
# 26   6.4   NaN       NaN
# 2.550151  NaN   NaN         NaN     NaN
# 2.380694  NaN   NaN         NaN     NaN
# 1.999009  NaN   NaN         NaN     NaN
# 3.077533  NaN   NaN         NaN     NaN
# 6.000000  0.2   NaN         NaN
# 2.251197  NaN   NaN         NaN     NaN
# 2.552369  NaN   NaN         NaN     NaN
# 3.935382  NaN   NaN         NaN     NaN
# 3.020821  NaN   NaN         NaN     NaN
# 4.096728  NaN   NaN         NaN     NaN
# 2.216686  NaN   NaN         NaN     NaN
# 1.000000  0.0   NaN         NaN
# ...       ...   ...         ...     ...
# 3.044602  NaN   NaN         NaN     NaN
# 2.407983  NaN   NaN         NaN     NaN
# 0.000000  9.8   NaN         NaN
# 2.816006  NaN   NaN         NaN     NaN
# 3.297657  NaN   NaN         NaN     NaN
# 2.668014  NaN   NaN         NaN     NaN
# 3.549488  NaN   NaN         NaN     NaN
# 3.159875  NaN   NaN         NaN     NaN
# 2.978442  NaN   NaN         NaN     NaN
# 2.232929  NaN   NaN         NaN     NaN
# 2.255760  NaN   NaN         NaN     NaN
# 2.262984  NaN   NaN         NaN     NaN
# 2.233999  NaN   NaN         NaN     NaN
# 2.529486  NaN   NaN         NaN     NaN
# 2.421672  NaN   NaN         NaN     NaN
# 3.000000  9.2   2.0  Lower body  102439
# 2.350163  NaN   NaN         NaN     NaN
# 2.816144  NaN   NaN         NaN     NaN
# 3.537758  NaN   NaN         NaN     NaN
# 2.923051  NaN   NaN         NaN     NaN
# 1.513665  NaN   NaN         NaN     NaN
# 2.074008  NaN   NaN         NaN     NaN
# 5.882353  NaN   NaN         NaN     NaN
# 2.389381  NaN   NaN         NaN     NaN
# 0.000000  9.8   NaN         NaN
# 3.064699  NaN   NaN         NaN     NaN
# 3.383333  NaN   NaN         NaN     NaN
# 2.606607  NaN   NaN         NaN     NaN
# 2.686629  NaN   NaN         NaN     NaN
# 2.943314  NaN   NaN         NaN     NaN
#
# [95 rows x 111 columns]
# /anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-856d7fccdb0a> in <module>()
#      23 # print(MergedDF)
#      24
# ---> 25 MergedDF = pd.concat([Injuries_df, GAA_df], axis = 1, ignore_index=True)
#      26 print(MergedDF)
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     224                        verify_integrity=verify_integrity,
#     225                        copy=copy, sort=sort)
# --> 226     return op.get_result()
#     227
#     228
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     421             new_data = concatenate_block_managers(
#     422                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# --> 423                 copy=self.copy)
#     424             if not self.copy:
#     425                 new_data._consolidate_inplace()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    5423         blocks.append(b)
#    5424
# -> 5425     return BlockManager(blocks, axes)
#    5426
#    5427
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in __init__(self, blocks, axes, do_integrity_check)
#    3280
#    3281         if do_integrity_check:
# -> 3282             self._verify_integrity()
#    3283
#    3284         self._consolidate_check()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in _verify_integrity(self)
#    3491         for block in self.blocks:
#    3492             if block._verify_integrity and block.shape[1:] != mgr_shape[1:]:
# -> 3493                 construction_error(tot_items, block.shape[1:], self.axes)
#    3494         if len(self.items) != tot_items:
#    3495             raise AssertionError('Number of manager items must equal union of '
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in construction_error(tot_items, block_shape, axes, e)
#    4841         raise ValueError("Empty data passed with indices specified.")
#    4842     raise ValueError("Shape of passed values is {0}, indices imply {1}".format(
# -> 4843         passed, implied))
#    4844
#    4845
#
# ValueError: Shape of passed values is (222, 150), indices imply (222, 146)

# %% [markdown]
# # Q6) Write a function(s)
# ## that subsets a dataframe by removing rows that are WITHIN the InterQuartile Region of a specified column
# <br> </br>
# ### The function takes as input
# ##### A: Pandas_Dataframe (For example use NHL_GoaliesDF)
# ##### B. Column name
# ### Add a condition that returns an error if the Column Name chosen is not:
# ##### A. Numeric Dtype
# ##### B. Does not exist in the Numeric Columns
# ### The output is a DataFrame that removes rows outside of the specified columns IQR
# <br> </br>
# <font color='red'>**You can use smaller helper functions **<font>
# <br> </br>
# See --> <href>=https://en.wikipedia.org/wiki/Interquartile_range</href>
# #hint: There are several pandas subfunctions that can be useful

# %%
#Answer Question 6 here
import pandas as pd
import numpy as np

# Function that determines if given value is NOT in interquartile range
# If value is not in IQR, function returns value; if value is IN IQR, it drops value

def get_non_subset_by_IQR(df, column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    iqr = (df[column] <= q1) | (df[column] >= q3)
    return df.loc[iqr]

NHL_Goalies = pd.read_excel('NHLGoalies2016_2017.xls',na_values='',sheet_name=0) # Load file
indexNames = get_non_subset_by_IQR(NHL_Goalies, "GP")

print(indexNames)
# Out:
#       Last Name First Name      Team         DOB        Birth City  S/P Cntry  \
# 0         Allen       Jake       STL  1990-08-07       Fredericton   NB   CAN
# 1         Alves      Jorge       CAR  1979-01-30            Boston   MA   USA
# 2      Andersen   Frederik       TOR  1989-10-02           Herning  NaN   DNK
# 4       Bachman    Richard       VAN  1987-07-25    Salt Lake City   UT   USA
# 8        Bibeau    Antoine       TOR  1994-05-01     Victoriaville   QC   CAN
# 10    Bobrovsky     Sergei       CBJ  1988-09-20      Novokuznetsk  NaN   RUS
# 12        Budaj      Peter  LAK, TBL  1982-09-18   Banská Bystrica  NaN   SVK
# 13     Campbell       Jack       LAK  1992-01-09        Port Huron   MI   USA
# 14       Comrie       Eric       WPG  1995-07-06          Edmonton   AB   CAN
# 16       Copley    Pheonix       STL  1992-01-18        North Pole   AK   USA
# 18     Crawford      Corey       CHI  1984-12-31          Montreal   QC   CAN
# 22     Driedger      Chris       OTT  1994-05-18          Winnipeg   MB   CAN
# 23       Dubnyk      Devan       MIN  1986-05-04            Regina   SK   CAN
# 27     Forsberg      Anton       CBJ  1992-11-27         Härnösand  NaN   SWE
# 28       Gibson       John       ANA  1993-07-14        Pittsburgh   PA   USA
# 29      Gillies        Jon       CGY  1994-01-22           Concord   NH   USA
# 30       Greiss     Thomas       NYI  1986-01-29            Fussen  NaN   DEU
# 32   Gudlevskis   Kristers       TBL  1992-07-31        Aizkraukle  NaN   LVA
# 36     Hellberg     Magnus       NYR  1991-04-04           Uppsala  NaN   SWE
# 37   Hellebuyck     Connor       WPG  1993-05-19          Commerce   MI   USA
# 38       Holtby     Braden       WSH  1989-09-16      Lloydminster   SK   CAN
# 42        Jarry    Tristan       PIT  1995-04-29            Surrey   BC   CAN
# 44        Jones     Martin       SJS  1990-01-10   North Vancouver   BC   CAN
# 50    Langhamer      Marek       ARI  1994-07-22  Moravska Trebova  NaN   CZE
# 51       Lehner      Robin       BUF  1991-07-24        Gothenburg  NaN   SWE
# 52     Lehtonen       Kari       DAL  1983-11-16          Helsinki  NaN   FIN
# 53     Leighton    Michael       CAR  1981-05-19          Petrolia   ON   CAN
# 54     Lindgren    Charlie       MTL  1993-12-18         Lakeville   MN   USA
# 55    Lundqvist     Henrik       NYR  1982-03-02               Are  NaN   SWE
# 58       Martin    Spencer       COL  1995-06-08          Oakville   ON   CAN
# 59        Mason      Steve       PHI  1988-05-29          Oakville   ON   CAN
# 60      Mazanec      Marek       NSH  1991-07-18             Pisek  NaN   CZE
# 63       Miller       Ryan       VAN  1980-07-17      East Lansing   MI   USA
# 65       Mrazek       Petr       DET  1992-02-14           Ostrava  NaN   CZE
# 67  Nedeljkovic       Alex       CAR  1996-01-07             Parma   OH   USA
# 72       Peters     Justin       ARI  1986-08-30             Blyth   ON   CAN
# 73      Pickard     Calvin       COL  1992-04-15           Moncton   NB   CAN
# 74        Price      Carey       MTL  1987-08-16       Anahim Lake   BC   CAN
# 77         Rask     Tuukka       BOS  1987-03-10        Savonlinna  NaN   FIN
# 79        Rinne      Pekka       NSH  1982-11-03           Kempele  NaN   FIN
# 80      Rittich      David       CGY  1992-08-19           Jihlava  NaN   CZE
# 82    Schneider       Cory       NJD  1986-03-18        Marblehead   MA   USA
# 84        Smith       Mike       ARI  1982-03-22          Kingston   ON   CAN
# 85      Stalock       Alex       MIN  1987-07-28          St. Paul   MN   USA
# 87       Subban    Malcolm       BOS  1993-12-21           Toronto   ON   CAN
# 88       Talbot        Cam       EDM  1987-07-05         Caledonia   ON   CAN
# 89     Tokarski     Dustin       ANA  1989-09-16            Watson   SK   CAN
# 90      Ullmark      Linus       BUF  1993-07-31           Lugnvik  NaN   SWE
# 92  Vasilevskiy     Andrei       TBL  1994-07-25            Tyumen  NaN   RUS
# 93         Ward        Cam       CAR  1984-02-29         Saskatoon   SK   CAN
#
#     Nat  Ht   Wt   ...      Cap Hit        Pace   1st  2nd   3rd  Star   GPS  \
# 0   CAN  74  203   ...    2350000.0  104.033662   9.0  7.0   6.0  22.0   9.8
# 1   USA  69  185   ...          NaN    0.000000   NaN  NaN   NaN   NaN   0.0
# 2   DNK  76  230   ...    5000000.0  118.931391   9.0  6.0   6.0  21.0  13.1
# 4   USA  70  183   ...     575000.0  113.421038   1.0  0.0   1.0   2.0   1.1
# 8   CAN  75  210   ...     655000.0  130.294240   NaN  NaN   NaN   NaN   0.4
# 10  RUS  74  182   ...    7425000.0  109.525950  17.0  6.0   6.0  29.0  14.9
# 12  SVK  73  196   ...     600000.0  108.110995   4.0  7.0   4.0  15.0   8.6
# 13  USA  74  197   ...          NaN   96.000000   NaN  NaN   NaN   NaN   0.1
# 14  CAN  73  175   ...     645000.0  124.451939   NaN  NaN   NaN   NaN   0.2
# 16  USA  76  196   ...     708750.0  104.864253   NaN  NaN   NaN   NaN  -0.1
# 18  CAN  74  216   ...    6000000.0  112.428393   8.0  5.0   0.0  13.0  11.0
# 22  CAN  76  205   ...     755000.0  123.000000   NaN  NaN   NaN   NaN  -0.2
# 23  CAN  78  213   ...    4333333.0  109.334753   8.0  6.0   8.0  22.0  13.1
# 27  SWE  75  192   ...     650000.0  110.611664   NaN  NaN   NaN   NaN   0.0
# 28  USA  75  226   ...    2300000.0  109.329402   7.0  8.0   2.0  17.0  10.3
# 29  USA  78  223   ...     925000.0  109.000000   1.0  0.0   0.0   1.0   0.3
# 30  DEU  73  228   ...    1500000.0  115.658454   2.0  6.0   6.0  14.0   8.6
# 32  LVA  75  223   ...          NaN  125.764192   NaN  NaN   NaN   NaN   0.0
# 36  SWE  78  209   ...     625000.0  111.568669   0.0  0.0   1.0   1.0   0.2
# 37  USA  76  207   ...     667500.0  107.597892   7.0  1.0   2.0  10.0   8.1
# 38  CAN  74  217   ...    6100000.0  109.755899  11.0  8.0   7.0  26.0  12.3
# 42  CAN  74  194   ...     630833.0  107.234043   NaN  NaN   NaN   NaN   0.0
# 44  CAN  76  190   ...    3000000.0  114.352625   9.0  1.0   6.0  16.0   9.9
# 50  CZE  74  193   ...     648333.0   88.936627   NaN  NaN   NaN   NaN   0.0
# 51  SWE  76  239   ...    2225000.0  110.839435   3.0  5.0   5.0  13.0  12.9
# 52  FIN  76  190   ...    5900000.0  114.649922   5.0  3.0   3.0  11.0   7.1
# 53  CAN  75  186   ...     700000.0  108.425141   1.0  0.0   0.0   1.0   0.1
# 54  USA  74  190   ...     925000.0   97.124076   0.0  0.0   1.0   1.0   0.6
# 55  SWE  73  188   ...    8500000.0  111.429541  14.0  2.0   1.0  17.0   9.1
# 58  CAN  75  210   ...     728333.0  110.013004   NaN  NaN   NaN   NaN   0.0
# 59  CAN  76  210   ...    4100000.0  113.576291   3.0  6.0   6.0  15.0   8.2
# 60  CZE  76  187   ...     575000.0  118.592210   NaN  NaN   NaN   NaN  -0.2
# 63  USA  74  168   ...    6000000.0  106.144434  10.0  4.0   3.0  17.0  10.3
# 65  CZE  74  183   ...    4000000.0  101.689696   3.0  4.0   6.0  13.0   6.5
# 67  USA  72  198   ...          NaN  102.170284   NaN  NaN   NaN   NaN   0.3
# 72  CAN  73  210   ...     600000.0  101.115987   NaN  NaN   NaN   NaN   0.3
# 73  CAN  73  200   ...    1000000.0  106.926059   3.0  4.0   8.0  15.0   7.1
# 74  CAN  75  226   ...    6500000.0  111.371400   9.0  9.0   6.0  24.0  12.6
# 77  FIN  75  176   ...    7000000.0  109.563799  14.0  4.0   8.0  26.0   9.8
# 79  FIN  77  217   ...    7000000.0  111.598705   5.0  9.0  10.0  24.0  11.3
# 80  CZE  75  202   ...          NaN  108.000000   NaN  NaN   NaN   NaN   0.0
# 82  USA  75  205   ...    6000000.0   99.791717   5.0  4.0   7.0  16.0   9.5
# 84  CAN  76  215   ...    5666667.0  115.348101   7.0  4.0   6.0  17.0  10.9
# 85  USA  72  187   ...     650000.0  100.911002   0.0  0.0   1.0   1.0   0.5
# 87  CAN  74  200   ...     863333.0  107.843137   NaN  NaN   NaN   NaN  -0.1
# 88  CAN  75  199   ...    4166667.0  112.035398  11.0  8.0   2.0  21.0  14.0
# 89  CAN  72  205   ...          NaN   91.993186   NaN  NaN   NaN   NaN   0.1
# 90  SWE  76  221   ...     775833.0  100.113507   NaN  NaN   NaN   NaN   0.2
# 92  RUS  75  207   ...     925000.0  108.651016   4.0  8.0   2.0  14.0   9.3
# 93  CAN  73  185   ...    3300000.0  108.609467   5.0  6.0   6.0  17.0   8.5
#
#     Ginj                       Injuries    CHIP
# 0    NaN                            NaN
# 1    NaN                            NaN
# 2    2.0                     Upper body  121951
# 4    NaN                            NaN
# 8    NaN                            NaN
# 10   2.0                        Illness  181098
# 12   NaN                            NaN
# 13   NaN                            NaN
# 14   NaN                            NaN
# 16   NaN                            NaN
# 18  11.0          Appendectomy, Illness  804878
# 22   NaN                            NaN
# 23   NaN                            NaN
# 27   NaN                            NaN
# 28  13.0                      Lowe body  364634
# 29   NaN                            NaN
# 30   NaN                            NaN
# 32   NaN                            NaN
# 36   NaN                            NaN
# 37   NaN                            NaN
# 38   NaN                            NaN
# 42   NaN                            NaN
# 44   NaN                            NaN
# 50   NaN                            NaN
# 51   7.0  Illness, Hip, Flu, Upper body  189939
# 52   NaN                            NaN
# 53   NaN                            NaN
# 54   NaN                            NaN
# 55   8.0                       Flu, Hip  829268
# 58   NaN                            NaN
# 59   1.0                        Illness   50000
# 60   NaN                            NaN
# 63   4.0        Undisclosed, Flu, Ankle  292683
# 65   NaN                            NaN
# 67   NaN                            NaN
# 72   NaN                            NaN
# 73   NaN                            NaN
# 74   3.0                            Flu  237805
# 77   4.0                     Lower body  341463
# 79   2.0            Illness, Lower body  170732
# 80   NaN                            NaN
# 82   NaN                            NaN
# 84  13.0            Lower body, Illness  898374
# 85   NaN                            NaN
# 87   NaN                            NaN
# 88   NaN                            NaN
# 89   NaN                            NaN
# 90   NaN                            NaN
# 92   NaN                            NaN
# 93   NaN                            NaN
#
# [50 rows x 111 columns]
